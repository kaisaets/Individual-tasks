# %% [markdown]
# <a href="https://colab.research.google.com/github/kaisaets/Individual-tasks/blob/main/17_08_2024_Python_individual_work_learning_from_Titanic_disaster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/archive.zip') #read the file

# %%
dataset.head() #looking at the first five values
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
dataset.shape #checking the number of rows and columns
# Out:
# (1313, 6)

# %%
#Identify missing values and decide on strategies for handling them
dataset.notna().all()
# Out:
# Name         True
# PClass       True
# Age         False
# Sex          True
# Survived     True
# SexCode      True
# dtype: bool

# %%
dataset.isna().sum() #how many empty values
# Out:
# Name          0
# PClass        0
# Age         557
# Sex           0
# Survived      0
# SexCode       0
# dtype: int64

# %%
#Drop empty values without overriding
dataset.dropna()
# Out:
#                                                Name PClass    Age     Sex  \
# 0                      Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                       Allison, Miss Helen Loraine    1st   2.00  female
# 2               Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3     Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                     Allison, Master Hudson Trevor    1st   0.92    male
# ...                                             ...    ...    ...     ...
# 1308                             Zakarian, Mr Artun    3rd  27.00    male
# 1309                         Zakarian, Mr Maprieder    3rd  26.00    male
# 1310                               Zenni, Mr Philip    3rd  22.00    male
# 1311                               Lievens, Mr Rene    3rd  24.00    male
# 1312                                 Zimmerman, Leo    3rd  29.00    male
#
#       Survived  SexCode
# 0            1        1
# 1            0        1
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1313 entries, 0 to 1312
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      1313 non-null   object
#  1   PClass    1313 non-null   object
#  2   Age       756 non-null    float64
#  3   Sex       1313 non-null   object
#  4   Survived  1313 non-null   int64
#  5   SexCode   1313 non-null   int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 61.7+ KB

# %%
#Compute basic statistics (e.g., mean, median, min, max) for numerical columns.
dataset['Age'].min()
# Out:
# 0.17

# %%
dataset['Age'].max()
# Out:
# 71.0

# %%
dataset['Age'].mean()
# Out:
# 30.397989417989418

# %%
dataset['Age'].median()
# Out:
# 28.0

# %%
#Analyze categorical variables (e.g., value counts)
dataset['Sex'].value_counts()
# Out:
# Sex
# male      851
# female    462
# Name: count, dtype: int64

# %%
dataset['Survived'].value_counts()
# Out:
# Survived
# 0    863
# 1    450
# Name: count, dtype: int64

# %%
dataset['SexCode'].value_counts()
# Out:
# SexCode
# 0    851
# 1    462
# Name: count, dtype: int64

# %%
dataset['PClass'].value_counts()
# Out:
# PClass
# 3rd    711
# 1st    322
# 2nd    279
# *        1
# Name: count, dtype: int64

# %%
#Choose one column of the dataset that interests you
plt.hist(dataset['Age'], bins=8, color='gray', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
#Median age was 28 and average 30 so it's nice to see a small confirmation here
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
#I used this to see the oldest person on board and decide how many bins to use on histogram
dataset.sort_values(by='Age', ascending=False)
# Out:
#                                                    Name PClass   Age     Sex  \
# 505                          Mitchell, Mr Henry Michael    2nd  71.0    male
# 119                            Goldschmidt, Mr George B    1st  71.0    male
# 9                                Artagaveytia, Mr Ramon    1st  71.0    male
# 72                       Crosby, Captain Edward Gifford    1st  70.0    male
# 73    Crosby, Mrs Edward Gifford (Catherine Elizabet...    1st  69.0  female
# ...                                                 ...    ...   ...     ...
# 1300                              Wiseman, Mr Phillippe    3rd   NaN    male
# 1302                                  Yalsevac, Mr Ivan    3rd   NaN    male
# 1305                                 Youssef, Mr Gerios    3rd   NaN    male
# 1306                                Zabour, Miss Hileni    3rd   NaN  female
# 1307                                Zabour, Miss Tamini    3rd   NaN  female
#
#       Survived  SexCode
# ...
